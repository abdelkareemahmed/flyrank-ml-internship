# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/abdelkareemahmed/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# Lane: Freestyle (Growth / Recovery / Momentum Prediction)
# I am choosing this freestyle direction to build a model that predicts which pages are likely to decline or recover in the future based on past performance windows. This approach is valuable because it shifts the strategy from reactive (fixing a page after traffic has already plummeted) to proactive (protecting a page before the drop solidifies). It also presents a strong technical challenge in engineering strict time windows to prevent data leakage.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# The Decision: Which visible pages should the content team prioritize for a refresh or monitoring to prevent an impending traffic drop?
#
# The Action: The content team will review the flagged candidate pages to update content, improve intent match, or adjust metadata.
#
# Cost of a wrong call: Flagging the wrong page wastes the team's limited time and resources on a page that was already stable or just experiencing normal seasonal fluctuations, while missing the pages that actually need urgent help.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# Load the starter dataset
df = pd.read_csv('data/raw/content_refresh_anonymized.csv')

# Calculate a few quick numbers to justify the problem
total_pages = len(df)
declining_pages = len(df[df['trend_direction'] == 'down'])
high_traffic_declining = len(df[(df['trend_direction'] == 'down') & (df['impressions_90d'] >= 500)])

print(f"Total pages in the starter dataset: {total_pages:,}")
print(f"Pages currently showing a downward trend: {declining_pages:,}")
print(f"High-exposure pages (>= 500 impressions) at risk of decline: {high_traffic_declining:,}")
# Out:
# Total pages in the starter dataset: 30,000
# Pages currently showing a downward trend: 16,262
# High-exposure pages (>= 500 impressions) at risk of decline: 9,961

# %% [markdown]
# What I can claim (Observed / Directional): This model provides directional decision-support. It ranks pages based on historical observable patterns that correlate with future drops, helping prioritize human review efficiently.
#
# What I can never claim (Causal proof): This work does not provide causal proof that a content refresh will guarantee a recovery. It also does not claim to predict or reverse-engineer Google's algorithm.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
